# %% [markdown]
# #### Exercise 16: Build , train and evaluate a neural network

# %%
import numpy as np
from si.data.dataset import Dataset
from si.model_selection.split import stratified_train_test_split
from si.neural_networks.neural_network import NeuralNetwork
from si.neural_networks.optimizers import SGD
from si.neural_networks.losses import BinaryCrossEntropy
from si.neural_networks.layers import DenseLayer, Layer, Dropout
from si.neural_networks.activation import ReLUActivation, SigmoidActivation
from si.metrics.accuracy import accuracy

# %% [markdown]
# Build train and evaluate a NN based on the following instructions
# - The training dataset has 32 features
# - The task is binary classification
# - Use the SGD optimizer
# - Use the BinaryCrossEntropy loss
# - Use the accuracy metric
# - The model should contain
#     - Dense layer 1
#     - ReLU activation layer 1
#     - Dense layer 2
#     - ReLU activation layer 2
#     - Output Dense layer
#     - Sigmoid activation layer
# - The dense layers should reduce the number of units to half (except the last one)
# - Train the NN for 100 epochs , with batch size of 16 with a learning rate of 0.01.
# - Test the model on na independent test set (you can create a random train and test set using numpy).

# %%
# create a dataset with 32 features

np.random.seed(42)
X = np.random.rand(960, 32)
y = np.random.randint(0, 2, 960)

dataset = Dataset(X, y)
print(dataset.shape())
dataset.summary()
# Out:
# (960, 32)
#           feat_0    feat_1    feat_2    feat_3    feat_4    feat_5    feat_6  \
# mean    0.500363  0.494429  0.500937  0.489289  0.512960  0.519171  0.507670
# median  0.506077  0.505868  0.507994  0.481400  0.516090  0.526934  0.516891
# min     0.001243  0.000330  0.000310  0.000053  0.000854  0.000195  0.000241
# max     0.999871  0.999558  0.999925  0.999137  0.999696  0.999673  0.999207
# var     0.078834  0.083717  0.081471  0.084621  0.083449  0.082250  0.084420
#
#           feat_7    feat_8    feat_9  ...   feat_22   feat_23   feat_24  \
# mean    0.507562  0.497840  0.487091  ...  0.498146  0.507426  0.496792
# median  0.510768  0.508137  0.472539  ...  0.495902  0.507312  0.500762
# min     0.001450  0.000125  0.003549  ...  0.000012  0.000031  0.000110
# max     0.999505  0.996145  0.999656  ...  0.997548  0.997983  0.999414
# var     0.084974  0.079576  0.084993  ...  0.082191  0.082102  0.082639
#
#          feat_25   feat_26   feat_27   feat_28   feat_29   feat_30   feat_31
# mean    0.492204  0.500203  0.504631  0.481091  0.502189  0.495744  0.491074
# median  0.481624  0.500033  0.496495  0.466123  0.501106  0.488433  0.482811
# min     0.000048  0.000410  0.003604  0.001146  0.000243  0.000906  0.000241
# max     0.999732  0.999805  0.996734  0.999350  0.999277  0.998934  0.998905
# var     0.081001  0.080214  0.084707  0.079331  0.081179  0.082434  0.086936
#
# [5 rows x 32 columns]

# %%
dataset.shape()[1]
# Out:
# 32

# %%
# split the dataset into train and test sets
train, test = stratified_train_test_split(dataset, test_size=0.2)
print(train.shape())
print(test.shape())
# Out:
# (769, 32)
# (191, 32)

# %%
# Instantiate NeuralNetwork
nn_model = NeuralNetwork(epochs=100, batch_size=16, optimizer=SGD, learning_rate=0.01,
                         verbose=True, loss=BinaryCrossEntropy, metric=accuracy)

# Add layers to the model
nn_model.add(DenseLayer(32, (dataset.shape()[1],)))
nn_model.add(ReLUActivation())
nn_model.add(DenseLayer(16))
nn_model.add(ReLUActivation())
nn_model.add(DenseLayer(1))
nn_model.add(SigmoidActivation())  

nn_model.fit(train)
# Epoch 51/100 - loss: 280.7499 - accuracy: 0.8359
# Epoch 52/100 - loss: 256.7801 - accuracy: 0.8633
# Epoch 53/100 - loss: 268.0829 - accuracy: 0.8320
# Epoch 54/100 - loss: 291.1219 - accuracy: 0.8320
# Epoch 55/100 - loss: 256.8347 - accuracy: 0.8568
# Epoch 56/100 - loss: 262.0500 - accuracy: 0.8542
# Epoch 57/100 - loss: 251.6162 - accuracy: 0.8438
# Epoch 58/100 - loss: 223.3812 - accuracy: 0.8763
# Epoch 59/100 - loss: 233.9933 - accuracy: 0.8711
# Epoch 60/100 - loss: 211.0745 - accuracy: 0.8854
# Epoch 61/100 - loss: 183.1642 - accuracy: 0.9036
# Epoch 62/100 - loss: 214.3580 - accuracy: 0.8789
# Epoch 63/100 - loss: 171.0708 - accuracy: 0.9154
# Epoch 64/100 - loss: 194.8061 - accuracy: 0.8932
# Epoch 65/100 - loss: 299.5916 - accuracy: 0.8255
# Epoch 66/100 - loss: 181.6754 - accuracy: 0.9049
# Epoch 67/100 - loss: 169.6329 - accuracy: 0.9141
# Epoch 68/100 - loss: 169.5723 - accuracy: 0.9049
# Epoch 69/100 - loss: 120.6359 - accuracy: 0.9492
# Epoch 70/100 - loss: 131.3325 - accuracy: 0.9414
# Epoch 71/100 - loss: 145.0104 - accuracy: 0.9323
# Epoch 72/100 - loss: 189.8043 - accuracy: 0.8932
# Epoch 73/100 - loss: 150.1365 - accuracy: 0.9336
# Epoch 74/100 - loss: 112.6991 - accuracy: 0.9518
# Epoch 75/100 - loss: 89.3227 - accuracy: 0.9661
# Epoch 76/100 - loss: 101.8368 - accuracy: 0.9518
# Epoch 77/100 - loss: 75.2367 - accuracy: 0.9714
# Epoch 78/100 - loss: 77.1680 - accuracy: 0.9740
# Epoch 79/100 - loss: 73.8764 - accuracy: 0.9753
# Epoch 80/100 - loss: 72.8705 - accuracy: 0.9740
# Epoch 81/100 - loss: 74.0927 - accuracy: 0.9674
# Epoch 82/100 - loss: 36.5120 - accuracy: 0.9948
# Epoch 83/100 - loss: 78.0115 - accuracy: 0.9740
# Epoch 84/100 - loss: 31.9240 - accuracy: 0.9987
# Epoch 85/100 - loss: 28.5566 - accuracy: 0.9961
# Epoch 86/100 - loss: 39.0714 - accuracy: 0.9935
# Epoch 87/100 - loss: 26.7418 - accuracy: 0.9948
# Epoch 88/100 - loss: 21.9812 - accuracy: 0.9974
# Epoch 89/100 - loss: 18.3968 - accuracy: 0.9987
# Epoch 90/100 - loss: 16.8935 - accuracy: 1.0000
# Epoch 91/100 - loss: 17.1168 - accuracy: 1.0000
# Epoch 92/100 - loss: 14.6352 - accuracy: 1.0000
# Epoch 93/100 - loss: 13.1985 - accuracy: 0.9987
# Epoch 94/100 - loss: 12.4200 - accuracy: 1.0000
# Epoch 95/100 - loss: 11.9093 - accuracy: 1.0000
# Epoch 96/100 - loss: 10.9524 - accuracy: 1.0000
# Epoch 97/100 - loss: 10.4022 - accuracy: 1.0000
# Epoch 98/100 - loss: 9.5098 - accuracy: 1.0000
# Epoch 99/100 - loss: 8.8516 - accuracy: 1.0000
# Epoch 100/100 - loss: 8.6088 - accuracy: 1.0000

# %%
score = nn_model.score(test)
print(score)
# Out:
# 0.5287958115183246
